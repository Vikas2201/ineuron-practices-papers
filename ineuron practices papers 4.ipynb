# %% [markdown]
# create a sample JSON object from titanic train dataset
#
# https://raw.githubusercontent.com/pcsanwald/kaggle-titanic/master/train.csv
# -----------------------------------------------------------------------------------

# %%
import pandas as pd
import json
url = "https://raw.githubusercontent.com/pcsanwald/kaggle-titanic/master/train.csv"
df = pd.read_csv(url)
df.head(10)
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# ...

# %% [markdown]
# Display a summary of the basic information about this DataFrame and its data.
# ---------------------------------------------------------------------------------------------

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   cabin     204 non-null    object
#  10  embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# Select some specific columns from the DataFrame.
# --------------------------------------------------------------

# %%
df[["cabin" , "fare" , "sex"]]
# Out:
#     cabin     fare     sex
# 0     NaN   7.2500    male
# 1     C85  71.2833  female
# 2     NaN   7.9250  female
# 3    C123  53.1000  female
# 4     NaN   8.0500    male
# ..    ...      ...     ...
# 886   NaN  13.0000    male
# 887   B42  30.0000  female
# 888   NaN  23.4500  female
# 889  C148  30.0000    male
# 890   NaN   7.7500    male
#
# [891 rows x 3 columns]

# %%
df.loc[:,["fare","sex"]]
# Out:
#         fare     sex
# 0     7.2500    male
# 1    71.2833  female
# 2     7.9250  female
# 3    53.1000  female
# 4     8.0500    male
# ..       ...     ...
# 886  13.0000    male
# 887  30.0000  female
# 888  23.4500  female
# 889  30.0000    male
# 890   7.7500    male
#
# [891 rows x 2 columns]

# %% [markdown]
# Select the data in rows [3, 4, 8] and in columns ['sex', 'age'].
# -----------------------------------------------------------------------

# %%
df.loc[df.index[[3,4,8]],["sex","age"]]
# Out:
#       sex   age
# 3  female  35.0
# 4    male  35.0
# 8  female  27.0

# %% [markdown]
# Select the rows where the age is missing.
# ---------------------------------------------

# %%
df[df["age"].isnull()]
# Out:
#      survived  pclass                                      name     sex  age  \
# 5           0       3                          Moran, Mr. James    male  NaN
# 17          1       2              Williams, Mr. Charles Eugene    male  NaN
# 19          1       3                   Masselmani, Mrs. Fatima  female  NaN
# 26          0       3                   Emir, Mr. Farred Chehab    male  NaN
# 28          1       3             O'Dwyer, Miss. Ellen "Nellie"  female  NaN
# ..        ...     ...                                       ...     ...  ...
# 859         0       3                          Razi, Mr. Raihed    male  NaN
# 863         0       3         Sage, Miss. Dorothy Edith "Dolly"  female  NaN
# 868         0       3               van Melkebeke, Mr. Philemon    male  NaN
# 878         0       3                        Laleff, Mr. Kristo    male  NaN
# 888         0       3  Johnston, Miss. Catherine Helen "Carrie"  female  NaN
#
# ...

# %%
df[df["embarked"]=='C']
# Out:
#      survived  pclass                                               name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 19          1       3                            Masselmani, Mrs. Fatima
# 26          0       3                            Emir, Mr. Farred Chehab
# 30          0       1                           Uruchurtu, Don. Manuel E
# ..        ...     ...                                                ...
# 866         1       2                       Duran y More, Miss. Asuncion
# 874         1       2              Abelson, Mrs. Samuel (Hannah Wizosky)
# 875         1       3                   Najib, Miss. Adele Kiamie "Jane"
# 879         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 889         1       1                              Behr, Mr. Karl Howell
#
#         sex   age  sibsp  parch         ticket     fare cabin embarked
# ...

# %% [markdown]
# Select the rows where the sex is male and the age is null.
# -------------------------------------------------------------

# %%
df[(df["sex"]=="male") & (df["age"].isnull())]
# Out:
#      survived  pclass                          name   sex  age  sibsp  parch  \
# 5           0       3              Moran, Mr. James  male  NaN      0      0
# 17          1       2  Williams, Mr. Charles Eugene  male  NaN      0      0
# 26          0       3       Emir, Mr. Farred Chehab  male  NaN      0      0
# 29          0       3           Todoroff, Mr. Lalio  male  NaN      0      0
# 36          1       3              Mamee, Mr. Hanna  male  NaN      0      0
# ..        ...     ...                           ...   ...  ...    ...    ...
# 839         1       1          Marechal, Mr. Pierre  male  NaN      0      0
# 846         0       3      Sage, Mr. Douglas Bullen  male  NaN      8      2
# 859         0       3              Razi, Mr. Raihed  male  NaN      0      0
# 868         0       3   van Melkebeke, Mr. Philemon  male  NaN      0      0
# 878         0       3            Laleff, Mr. Kristo  male  NaN      0      0
#
#        ticket     fare cabin embarked
# ...

# %% [markdown]
# Select the rows the age is between 54 and 100 (inclusive).
# --------------------------------------------------------------

# %%
df[df["age"].between(54,100)]
# Out:
#      survived  pclass                                              name  \
# 6           0       1                           McCarthy, Mr. Timothy J
# 11          1       1                          Bonnell, Miss. Elizabeth
# 15          1       2                  Hewlett, Mrs. (Mary D Kingcome)
# 33          0       2                             Wheadon, Mr. Edward H
# 54          0       1                    Ostby, Mr. Engelhart Cornelius
# 94          0       3                                 Coxon, Mr. Daniel
# 96          0       1                         Goldschmidt, Mr. George B
# 116         0       3                              Connors, Mr. Patrick
# 124         0       1                       White, Mr. Percival Wayland
# 152         0       3                                  Meo, Mr. Alfonzo
# 170         0       1                         Van der hoef, Mr. Wyckoff
# 174         0       1                           Smith, Mr. James Clinch
# ...

# %% [markdown]
# Calculate the mean age for each different sex in df.
# -------------------------------------------------------

# %%
df.groupby("sex")["age"].mean()
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
df.groupby("embarked")["age"].mean()
# Out:
# embarked
# C    30.814769
# Q    28.089286
# S    29.445397
# Name: age, dtype: float64

# %% [markdown]
# Count the number of each type of sex , cabin , embarked , pclass in df.
# -------------------------------------------------------------------------

# %%
df["age"].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: age, Length: 88, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
df["embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
df["cabin"].value_counts()
# Out:
# G6             4
# B96 B98        4
# C23 C25 C27    4
# E101           3
# C22 C26        3
#               ..
# E17            1
# D30            1
# B86            1
# A34            1
# A7             1
# Name: cabin, Length: 147, dtype: int64

# %% [markdown]
# Sort df first by the values in the 'age' in decending order, then by the value in the 'fare' column in ascending order.
# -----------------------------------------------------------------------------------------------------------------------------

# %%
df.sort_values(by = ["age" , "fare"] , ascending = [False , True])
# Out:
#      survived  pclass                                               name  \
# 630         1       1               Barkworth, Mr. Algernon Henry Wilson
# 851         0       3                                Svensson, Mr. Johan
# 96          0       1                          Goldschmidt, Mr. George B
# 493         0       1                            Artagaveytia, Mr. Ramon
# 116         0       3                               Connors, Mr. Patrick
# ..        ...     ...                                                ...
# 306         1       1                            Fleming, Miss. Margaret
# 334         1       1  Frauenthal, Mrs. Henry William (Clara Heinshei...
# 31          1       1     Spencer, Mrs. William Augustus (Marie Eugenie)
# 527         0       1                                 Farthing, Mr. John
# 557         0       1                                Robbins, Mr. Victor
#
#         sex   age  sibsp  parch    ticket      fare cabin embarked
# ...
